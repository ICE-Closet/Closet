# %% [markdown]
# ## 옷 종류

# %%
top={'black_none_longsleeve','white_none_longsleeve','blue_none_longsleeve','red_none_longsleeve','gray_none_longsleeve','yellow_none_longsleeve','khaki_none_longsleeve', 'beige_none_longsleeve','pink_none_longsleeve', 'purple_none_longsleeve',
'black_none_longshirt','white_none_longshirt','gray_none_longshirt','beige_none_longshirt',
'black_none_longneat', 'white_none_longneat', 'gray_none_longneat', 'beige_none_longneat',
'black_none_shortsleeve','white_none_shortsleeve', 'blue_none_shortsleeve','red_none_shortsleeve','gray_none_shortsleeve','yellow_none_shortsleeve','khaki_none_shortsleeve','beige_none_shortsleeve','pink_none_shortsleeve','purple_none_shortsleeve',
'cnone_flower_longshirt','cnone_flower_shortshirt',
'black_stripe_longsleeve','red_stripe_longsleeve','yellow_stripe_longsleeve',
'black_stripe_shortsleeve','red_stripe_shortsleeve','yellow_stripe_shortsleeve',
'black_check_longshirt','blue_check_longshirt','red_check_longshirt','yellow_check_longshirt',
'black_check_shortshirt','blue_check_shortshirt','red_check_shortshirt','yellow_check_shortshirt',
'black_nike_longsleeve','white_nike_longsleeve',
'black_nike_shortsleeve','white_nike_shortsleeve',
'black_none_sleeveless','white_none_sleeveless'
}
print("top: ",len(top))

bottom={'black_none_longpants','white_none_longpants','lightblue_none_longpants','blue_none_longpants','gray_none_longpants','beige_none_longpants',
'black_none_shortpants','white_none_shortpants','lightblue_none_shortpants','blue_none_shortpants','gray_none_shortpants','beige_none_shortpants','red_none_shortpants',
'black_none_longskirt','white_none_longskirt','lightblue_none_longskirt','blue_none_longskirt','beige_none_longskirt',
'black_none_shortskirt','white_none_shortskirt','lightblue_none_shortskirt','blue_none_shortskirt','beige_none_shortskirt',
'black_none_adidaslongpants','black_none_adidasshortpants','black_none_joggerpants'
}
print("bottom: ",len(bottom))

dress={'black_none_sumlongdress','white_none_sumlongdress','blue_none_sumlongdress','red_none_sumlongdress','beige_none_sumlongdress',
'black_none_sumshortdress','white_none_sumshortdress','blue_none_sumshortdress','red_none_sumshortdress','beige_none_sumshortdress',
'black_none_winlongdress','white_none_winlongdress','blue_none_winlongdress','red_none_winlongdress','beige_none_winlongdress',
'black_none_winshortdress','white_none_winshortdress','blue_none_winshortdress','red_none_winshortdress','beige_none_winshortdress'
}
print("dress: ",len(dress))

outer={'black_none_cardigan','gray_none_cardigan','brown_none_cardigan',
'black_none_hoodie','gray_none_hoodie','brown_none_hoodie',
'black_none_coat','gray_none_coat','brown_none_coat',
'black_none_ma1','khaki_none_ma1',
'black_none_blazer','gray_none_blazer',
'blue_none_jacket','black_none_riderjacket',
'black_none_parka','white_none_parka',
'black_none_neatvest','gray_none_neatvest',
}
print("outer: ",len(outer))
# Out:
# top:  50
# bottom:  26
# dress:  20
# outer:  19

# %% [markdown]
# ## top, bottom, dress, outer

# %%
# 27 ~ :sleeveless, shortsleeve, shortshirt
ts={'27':['black_none_shortsleeve','white_none_shortsleeve', 'blue_none_shortsleeve','red_none_shortsleeve','gray_none_shortsleeve','yellow_none_shortsleeve','khaki_none_shortsleeve','beige_none_shortsleeve','pink_none_shortsleeve','purple_none_shortsleeve',
          'black_nike_shortsleeve','white_nike_shortsleeve',
          'black_stripe_shortsleeve','red_stripe_shortsleeve','yellow_stripe_shortsleeve',
          'black_check_shortshirt','blue_check_shortshirt','red_check_shortshirt','yellow_check_shortshirt',
          'cnone_flower_shortshirt',
          'black_none_sleeveless','white_none_sleeveless'
         ]}

# 26 ~ 23 :shortshirt, shortsleeve
ts_tt={'26':['black_none_shortsleeve','white_none_shortsleeve', 'blue_none_shortsleeve','red_none_shortsleeve','gray_none_shortsleeve','yellow_none_shortsleeve','khaki_none_shortsleeve','beige_none_shortsleeve','pink_none_shortsleeve','purple_none_shortsleeve',
             'black_nike_shortsleeve','white_nike_shortsleeve',
             'black_stripe_shortsleeve','red_stripe_shortsleeve','yellow_stripe_shortsleeve',
             'black_check_shortshirt','blue_check_shortshirt','red_check_shortshirt','yellow_check_shortshirt',
             'cnone_flower_shortshirt']}

# 22 ~ 20 : 22-1 longsleeve, longshirt
tt_t1={'22-1':['black_none_longsleeve','white_none_longsleeve','blue_none_longsleeve','red_none_longsleeve','gray_none_longsleeve','yellow_none_longsleeve','khaki_none_longsleeve', 'beige_none_longsleeve','pink_none_longsleeve', 'purple_none_longsleeve',
               'black_stripe_longsleeve','red_stripe_longsleeve','yellow_stripe_longsleeve',
               'black_nike_longsleeve','white_nike_longsleeve',
               'black_none_longshirt','white_none_longshirt','gray_none_longshirt','beige_none_longshirt',
               'cnone_flower_longshirt',
               'black_check_longshirt','blue_check_longshirt','red_check_longshirt','yellow_check_longshirt']}
# 22-2:shortshirt, shortsleeve 
tt_t1['22-2']=['black_none_shortsleeve','white_none_shortsleeve', 'blue_none_shortsleeve','red_none_shortsleeve','gray_none_shortsleeve','yellow_none_shortsleeve','khaki_none_shortsleeve','beige_none_shortsleeve','pink_none_shortsleeve','purple_none_shortsleeve',
               'black_nike_shortsleeve','white_nike_shortsleeve',
               'black_stripe_shortsleeve','red_stripe_shortsleeve','yellow_stripe_shortsleeve',
               'black_check_shortshirt','blue_check_shortshirt','red_check_shortshirt','yellow_check_shortshirt',
               'cnone_flower_shortshirt']

# 19 ~ 17:longsleeve, longshirt
on_os1={'19-1': ['black_none_longsleeve','white_none_longsleeve','blue_none_longsleeve','red_none_longsleeve','gray_none_longsleeve','yellow_none_longsleeve','khaki_none_longsleeve', 'beige_none_longsleeve','pink_none_longsleeve', 'purple_none_longsleeve',
                 'black_stripe_longsleeve','red_stripe_longsleeve','yellow_stripe_longsleeve',
                 'black_nike_longsleeve','white_nike_longsleeve',
                 'black_none_longshirt','white_none_longshirt','gray_none_longshirt','beige_none_longshirt',
                 'cnone_flower_longshirt',
                 'black_check_longshirt','blue_check_longshirt','red_check_longshirt','yellow_check_longshirt']}

on_os1['19-2']=['black_none_longneat', 'white_none_longneat', 'gray_none_longneat', 'beige_none_longneat']


# 16 ~ 10 : 16-1: longsleeve, longneat, longshirt
os_o1={'16-1': ['black_none_longsleeve','white_none_longsleeve','blue_none_longsleeve','red_none_longsleeve','gray_none_longsleeve','yellow_none_longsleeve','khaki_none_longsleeve', 'beige_none_longsleeve','pink_none_longsleeve', 'purple_none_longsleeve',
                'black_stripe_longsleeve','red_stripe_longsleeve','yellow_stripe_longsleeve',
                'black_nike_longsleeve','white_nike_longsleeve',
                'black_none_longshirt','white_none_longshirt','gray_none_longshirt','beige_none_longshirt',
                'cnone_flower_longshirt',
                'black_check_longshirt','blue_check_longshirt','red_check_longshirt','yellow_check_longshirt',
                'black_none_longneat', 'white_none_longneat', 'gray_none_longneat', 'beige_none_longneat']} 
#16-2 : longsleeve, longshirt
os_o1['16-2']=['black_none_longsleeve','white_none_longsleeve','blue_none_longsleeve','red_none_longsleeve','gray_none_longsleeve','yellow_none_longsleeve','khaki_none_longsleeve', 'beige_none_longsleeve','pink_none_longsleeve', 'purple_none_longsleeve',
               'black_stripe_longsleeve','red_stripe_longsleeve','yellow_stripe_longsleeve',
               'black_nike_longsleeve','white_nike_longsleeve',
               'black_none_longshirt','white_none_longshirt','gray_none_longshirt','beige_none_longshirt',
               'cnone_flower_longshirt',
               'black_check_longshirt','blue_check_longshirt','red_check_longshirt','yellow_check_longshirt']

# 9 ~ 6 : 9-1:longsleeve, longneat, longshirt
n_s1={'9-1':['black_none_longsleeve','white_none_longsleeve','blue_none_longsleeve','red_none_longsleeve','gray_none_longsleeve','yellow_none_longsleeve','khaki_none_longsleeve', 'beige_none_longsleeve','pink_none_longsleeve', 'purple_none_longsleeve',
             'black_stripe_longsleeve','red_stripe_longsleeve','yellow_stripe_longsleeve',
             'black_nike_longsleeve','white_nike_longsleeve',
             'black_none_longshirt','white_none_longshirt','gray_none_longshirt','beige_none_longshirt',
             'cnone_flower_longshirt',
             'black_check_longshirt','blue_check_longshirt','red_check_longshirt','yellow_check_longshirt',
             'black_none_longneat', 'white_none_longneat', 'gray_none_longneat', 'beige_none_longneat']} 
# 9-2: longsleeve, longshirt
n_s1['9-2']=['black_none_longsleeve','white_none_longsleeve','blue_none_longsleeve','red_none_longsleeve','gray_none_longsleeve','yellow_none_longsleeve','khaki_none_longsleeve', 'beige_none_longsleeve','pink_none_longsleeve', 'purple_none_longsleeve',
             'black_stripe_longsleeve','red_stripe_longsleeve','yellow_stripe_longsleeve',
             'black_nike_longsleeve','white_nike_longsleeve',
             'black_none_longshirt','white_none_longshirt','gray_none_longshirt','beige_none_longshirt',
             'cnone_flower_longshirt',
             'black_check_longshirt','blue_check_longshirt','red_check_longshirt','yellow_check_longshirt']


# 5 ~ : 5-1: longsleeve, longneat, longshirt
f1={'5-1': n_s1["9-1"]} 
# 5 -2 : 
f1['5-2']= n_s1["9-2"]

# %%
total={}
total.update(ts)
total.update(ts_tt)
total.update(tt_t1)
total.update(on_os1)
total.update(os_o1)
total.update(n_s1)
total.update(f1)

# %%
import pandas as pd
import numpy as np
df1 = pd.DataFrame.from_dict(total, orient='index')
df1 = df1.T
df1
# Out:
#                            27                         26  \
# 0      black_none_shortsleeve     black_none_shortsleeve
# 1      white_none_shortsleeve     white_none_shortsleeve
# 2       blue_none_shortsleeve      blue_none_shortsleeve
# 3        red_none_shortsleeve       red_none_shortsleeve
# 4       gray_none_shortsleeve      gray_none_shortsleeve
# 5     yellow_none_shortsleeve    yellow_none_shortsleeve
# 6      khaki_none_shortsleeve     khaki_none_shortsleeve
# 7      beige_none_shortsleeve     beige_none_shortsleeve
# 8       pink_none_shortsleeve      pink_none_shortsleeve
# 9     purple_none_shortsleeve    purple_none_shortsleeve
# 10     black_nike_shortsleeve     black_nike_shortsleeve
# 11     white_nike_shortsleeve     white_nike_shortsleeve
# 12   black_stripe_shortsleeve   black_stripe_shortsleeve
# 13     red_stripe_shortsleeve     red_stripe_shortsleeve
# 14  yellow_stripe_shortsleeve  yellow_stripe_shortsleeve
# ...

# %%
# 27 ~
bts={"27": ['black_none_shortpants','white_none_shortpants','lightblue_none_shortpants','blue_none_shortpants','gray_none_shortpants','beige_none_shortpants','red_none_shortpants',
            'black_none_longskirt','white_none_longskirt','lightblue_none_longskirt','blue_none_longskirt','beige_none_longskirt',
            'black_none_shortskirt','white_none_shortskirt','lightblue_none_shortskirt','blue_none_shortskirt','beige_none_shortskirt',
            'black_none_adidasshortpants']}

# 26 ~ 23
bts_tt={"26": ['black_none_longpants','white_none_longpants','lightblue_none_longpants','blue_none_longpants','gray_none_longpants','beige_none_longpants',
               'black_none_shortpants','white_none_shortpants','lightblue_none_shortpants','blue_none_shortpants','gray_none_shortpants','beige_none_shortpants','red_none_shortpants',
               'black_none_longskirt','white_none_longskirt','lightblue_none_longskirt','blue_none_longskirt','beige_none_longskirt',
               'black_none_shortskirt','white_none_shortskirt','lightblue_none_shortskirt','blue_none_shortskirt','beige_none_shortskirt',
               'black_none_adidaslongpants','black_none_adidasshortpants','black_none_joggerpants']} 

# 22 ~ 20 
btt_t1={"22-1":['black_none_longpants','white_none_longpants','lightblue_none_longpants','blue_none_longpants','gray_none_longpants','beige_none_longpants',
                'black_none_shortpants','white_none_shortpants','lightblue_none_shortpants','blue_none_shortpants','gray_none_shortpants','beige_none_shortpants','red_none_shortpants',
                'black_none_longskirt','white_none_longskirt','lightblue_none_longskirt','blue_none_longskirt','beige_none_longskirt',
                'black_none_shortskirt','white_none_shortskirt','lightblue_none_shortskirt','blue_none_shortskirt','beige_none_shortskirt',
                'black_none_adidaslongpants','black_none_adidasshortpants','black_none_joggerpants']} 

btt_t1["22-2"]=['black_none_longpants','white_none_longpants','lightblue_none_longpants','blue_none_longpants','gray_none_longpants','beige_none_longpants',
                'black_none_longskirt','white_none_longskirt','lightblue_none_longskirt','blue_none_longskirt','beige_none_longskirt',
                'black_none_shortskirt','white_none_shortskirt','lightblue_none_shortskirt','blue_none_shortskirt','beige_none_shortskirt',
                'black_none_adidaslongpants','black_none_joggerpants']

# 19 ~ 17
bon_os1={"19-1": ['black_none_longpants','white_none_longpants','lightblue_none_longpants','blue_none_longpants','gray_none_longpants','beige_none_longpants',
                  'black_none_longskirt','white_none_longskirt','lightblue_none_longskirt','blue_none_longskirt','beige_none_longskirt',
                  'black_none_shortskirt','white_none_shortskirt','lightblue_none_shortskirt','blue_none_shortskirt','beige_none_shortskirt',
                  'black_none_adidaslongpants','black_none_joggerpants']}
bon_os1["19-2"]=['black_none_longpants','white_none_longpants','lightblue_none_longpants','blue_none_longpants','gray_none_longpants','beige_none_longpants',
                  'black_none_longskirt','white_none_longskirt','lightblue_none_longskirt','blue_none_longskirt','beige_none_longskirt',
                  'black_none_shortskirt','white_none_shortskirt','lightblue_none_shortskirt','blue_none_shortskirt','beige_none_shortskirt']

# 16 ~ 10
bos_o1={"16": ['black_none_longpants','white_none_longpants','lightblue_none_longpants','blue_none_longpants','gray_none_longpants','beige_none_longpants',
               'black_none_longskirt','white_none_longskirt','lightblue_none_longskirt','blue_none_longskirt','beige_none_longskirt',
               'black_none_shortskirt','white_none_shortskirt','lightblue_none_shortskirt','blue_none_shortskirt','beige_none_shortskirt',
               'black_none_adidaslongpants','black_none_joggerpants']}

# 9 ~ 6, 5 ~
bn_s1={"9":['black_none_longpants','white_none_longpants','lightblue_none_longpants','blue_none_longpants','gray_none_longpants','beige_none_longpants',
            'black_none_longskirt','white_none_longskirt','lightblue_none_longskirt','blue_none_longskirt','beige_none_longskirt',
            'black_none_adidaslongpants','black_none_joggerpants']}

# %%
total2={}
total2.update(bts)
total2.update(bts_tt)
total2.update(btt_t1)
total2.update(bon_os1)
total2.update(bos_o1)
total2.update(bn_s1)

# %%
df2 = pd.DataFrame.from_dict(total2, orient='index')
df2 = df2.T
df2
# Out:
#                              27                           26  \
# 0         black_none_shortpants         black_none_longpants
# 1         white_none_shortpants         white_none_longpants
# 2     lightblue_none_shortpants     lightblue_none_longpants
# 3          blue_none_shortpants          blue_none_longpants
# 4          gray_none_shortpants          gray_none_longpants
# 5         beige_none_shortpants         beige_none_longpants
# 6           red_none_shortpants        black_none_shortpants
# 7          black_none_longskirt        white_none_shortpants
# 8          white_none_longskirt    lightblue_none_shortpants
# 9      lightblue_none_longskirt         blue_none_shortpants
# 10          blue_none_longskirt         gray_none_shortpants
# 11         beige_none_longskirt        beige_none_shortpants
# 12        black_none_shortskirt          red_none_shortpants
# 13        white_none_shortskirt         black_none_longskirt
# ...

# %%
# 27 ~
dts={"27":['black_none_sumshortdress','white_none_sumshortdress','blue_none_sumshortdress','red_none_sumshortdress','beige_none_sumshortdress']}

# 26 ~ 23
dts_tt={"26":['black_none_sumlongdress','white_none_sumlongdress','blue_none_sumlongdress','red_none_sumlongdress','beige_none_sumlongdress',
              'black_none_sumshortdress','white_none_sumshortdress','blue_none_sumshortdress','red_none_sumshortdress','beige_none_sumshortdress']}

# 22 ~ 20 
dtt_t1={"22-1":['black_none_winshortdress','white_none_winshortdress','blue_none_winshortdress','red_none_winshortdress','beige_none_winshortdress']}

dtt_t1["22-2"]=['black_none_winlongdress','white_none_winlongdress','blue_none_winlongdress','red_none_winlongdress','beige_none_winlongdress',
                'black_none_winshortdress','white_none_winshortdress','blue_none_winshortdress','red_none_winshortdress','beige_none_winshortdress']

# 19 ~ 17, # 16 ~ 10, 9 ~ 6, 5 ~
don_os={"19":['black_none_winlongdress','white_none_winlongdress','blue_none_winlongdress','red_none_winlongdress','beige_none_winlongdress',
              'black_none_winshortdress','white_none_winshortdress','blue_none_winshortdress','red_none_winshortdress','beige_none_winshortdress']}

# %%
total3={}
total3.update(dts)
total3.update(dts_tt)
total3.update(dtt_t1)
total3.update(don_os)

# %%
df3 = pd.DataFrame.from_dict(total3,orient='index')
df3 = df3.T
df3
# Out:
#                          27                        26  \
# 0  black_none_sumshortdress   black_none_sumlongdress
# 1  white_none_sumshortdress   white_none_sumlongdress
# 2   blue_none_sumshortdress    blue_none_sumlongdress
# 3    red_none_sumshortdress     red_none_sumlongdress
# 4  beige_none_sumshortdress   beige_none_sumlongdress
# 5                      None  black_none_sumshortdress
# 6                      None  white_none_sumshortdress
# 7                      None   blue_none_sumshortdress
# 8                      None    red_none_sumshortdress
# 9                      None  beige_none_sumshortdress
#
#                        22-1                      22-2  \
# 0  black_none_winshortdress   black_none_winlongdress
# 1  white_none_winshortdress   white_none_winlongdress
# 2   blue_none_winshortdress    blue_none_winlongdress
# 3    red_none_winshortdress     red_none_winlongdress
# 4  beige_none_winshortdress   beige_none_winlongdress
# ...

# %%
#+["None" for i in range(5)]

# 22 ~ 20 : gardigan
ptt_t={"22":['brown_none_cardigan', 'gray_none_cardigan', 'black_none_cardigan']}

# 19 ~ 17 : 19-1: vest, gardigan, hoodie, jacket
pon_os1={"19-1":['black_none_vest','gray_none_vest','blue_none_jacket'
                'black_none_cardigan','gray_none_cardigan','brown_none_cardigan',
                'black_none_hoodie','gray_none_hoodie','brown_none_hoodie']}
# 19 -1 :jacket, gardigan
pon_os1["19-2"]=['blue_none_jacket',
                 'brown_none_cardigan','gray_none_cardigan', 'black_none_cardigan']

# 16 ~ 10 : 16-1 : gardigan, hoodie, ma-1, jacket, blezer, rider
pos_o1={"16-1":['brown_none_cardigan','gray_none_cardigan', 'black_none_cardigan',
                'black_none_hoodie','gray_none_hoodie','brown_none_hoodie',
                'black_none_ma1','khaki_none_ma1',
                'blue_none_jacket','black_none_riderjacket',
                'black_none_blazer','gray_none_blazer']}
# 16 -2: gardigan, jacket
pos_o1["16-2"]= ['blue_none_jacket',
                 'brown_none_cardigan','gray_none_cardigan', 'black_none_cardigan']
# oos_o1["16-2"] + vest

# 9 ~ 6 : 9-1: rider, coat, parka
pn_s1={"9-1":['black_none_parka','white_none_parka',
             'black_none_coat','gray_none_coat','brown_none_coat',
             'black_none_riderjacket']}
# 9-2: coat, parka
pn_s1["9-2"]=['black_none_parka','white_none_parka',
             'black_none_coat','gray_none_coat','brown_none_coat']
#n_s1["9-2"] + vest!

# 9-3_1:gardigan, hoodie
pn_s1["9-3_1"]=['brown_none_cardigan','gray_none_cardigan', 'black_none_cardigan',
               'black_none_hoodie','gray_none_hoodie','brown_none_hoodie']
# 9-3_2: coat, rider, ma-1
pn_s1["9-3_2"]=['black_none_coat','gray_none_coat','brown_none_coat',
                'black_none_riderjacket', 'black_none_ma1','khaki_none_ma1']

# n_s1["9-3_1"] + n_s1["9-3_2"]

# 5 ~ : 5-1: coat, parka
pf1={"5-1":pn_s1["9-2"]}
#그냥 f1["5-1"]이랑, f1["5-1"] + vest !!

# 5-2_1: rider, jacket, hoodie, gardigan
pf1["5-2_1"]=['brown_none_cardigan','gray_none_cardigan', 'black_none_cardigan',
             'black_none_hoodie','gray_none_hoodie','brown_none_hoodie',
             'blue_none_jacket','black_none_riderjacket']
# 5-2_2: coar, parka
pf1["5-2_2"]=pn_s1["9-2"]
 #그냥 f1["5-2_1"] + f1["5-2_2"] 이랑, f1["5-2_1"] + f1["5-2_2"] + vest !!

pf1["5-2_3"]=['brown_none_cardigan','gray_none_cardigan', 'black_none_cardigan','blue_none_jacket']

pf1["5-2_4"]=['brown_none_cardigan','gray_none_cardigan', 'black_none_cardigan','blue_none_jacket','black_none_riderjacket']

#vest
vest=['black_none_neatvest','gray_none_neatvest']

# %%
total4={}
total4.update(ptt_t)
total4.update(pon_os1)
total4.update(pos_o1)
total4.update(pn_s1)
total4.update(pf1)

# %%
df4 = pd.DataFrame.from_dict(total4, orient='index')
df4 = df4.T
df4
# Out:
#                      22                                 19-1  \
# 0   brown_none_cardigan                      black_none_vest
# 1    gray_none_cardigan                       gray_none_vest
# 2   black_none_cardigan  blue_none_jacketblack_none_cardigan
# 3                  None                   gray_none_cardigan
# 4                  None                  brown_none_cardigan
# 5                  None                    black_none_hoodie
# 6                  None                     gray_none_hoodie
# 7                  None                    brown_none_hoodie
# 8                  None                                 None
# 9                  None                                 None
# 10                 None                                 None
# 11                 None                                 None
#
#                    19-2                    16-1                 16-2  \
# 0      blue_none_jacket     brown_none_cardigan     blue_none_jacket
# ...

# %% [markdown]
# ## 기온에 따른 옷 조합

# %% [markdown]
# ### 27도

# %%
twentyseven=pd.DataFrame(columns=["top","bottom","dress","outer"])

# %%
#twenty_seven_1 : top+bottom
twentyseven_1= pd.MultiIndex.from_product((set(ts["27"])-{"None"}, set(bts["27"])-{"None"}))
twentyseven_1=pd.DataFrame(twentyseven_1)
for i in twentyseven_1[0].tolist():
    twentyseven = twentyseven.append({"top":i[0],"bottom":i[1]},ignore_index=True)
twentyseven
# Out:
#                         top                       bottom dress outer
# 0     gray_none_shortsleeve         gray_none_shortpants   NaN   NaN
# 1     gray_none_shortsleeve        beige_none_shortpants   NaN   NaN
# 2     gray_none_shortsleeve          red_none_shortpants   NaN   NaN
# 3     gray_none_shortsleeve         beige_none_longskirt   NaN   NaN
# 4     gray_none_shortsleeve         blue_none_shortpants   NaN   NaN
# ..                      ...                          ...   ...   ...
# 391  black_nike_shortsleeve        black_none_shortpants   NaN   NaN
# 392  black_nike_shortsleeve        white_none_shortpants   NaN   NaN
# 393  black_nike_shortsleeve  black_none_adidasshortpants   NaN   NaN
# 394  black_nike_shortsleeve    lightblue_none_shortpants   NaN   NaN
# 395  black_nike_shortsleeve          blue_none_longskirt   NaN   NaN
#
# [396 rows x 4 columns]

# %%
#twenty_seven_1 : dress
idx_d=df3[df3["27"]==None].index
twentyseven_2= df3["27"].drop(idx_d)
twentyseven_2
for i in twentyseven_2.tolist():
    if i != None:
        print(i)
        twentyseven = twentyseven.append({"dress":i},ignore_index=True)
twentyseven
# Out:
# black_none_sumshortdress
# white_none_sumshortdress
# blue_none_sumshortdress
# red_none_sumshortdress
# beige_none_sumshortdress
#                        top                 bottom                     dress  \
# 0    gray_none_shortsleeve   gray_none_shortpants                       NaN
# 1    gray_none_shortsleeve  beige_none_shortpants                       NaN
# 2    gray_none_shortsleeve    red_none_shortpants                       NaN
# 3    gray_none_shortsleeve   beige_none_longskirt                       NaN
# 4    gray_none_shortsleeve   blue_none_shortpants                       NaN
# ..                     ...                    ...                       ...
# 396                    NaN                    NaN  black_none_sumshortdress
# 397                    NaN                    NaN  white_none_sumshortdress
# 398                    NaN                    NaN   blue_none_sumshortdress
# 399                    NaN                    NaN    red_none_sumshortdress
# ...

# %%
pd.DataFrame(twentyseven).to_csv("27_fashion.csv",mode="w")

# %% [markdown]
# ### 26 ~ 23도

# %%
twentysix_twentythree = pd.DataFrame(columns=["top","bottom","dress","outer"])

# %%
# twentysix_twentythree_1 : top + bottom
twentysix_twentythree_1 = pd.MultiIndex.from_product((set(ts_tt["26"])-{"None"}, set(bts_tt["26"])-{"None"}))
twentysix_twentythree_1 = pd.DataFrame(twentysix_twentythree_1)

for i in twentysix_twentythree_1[0].tolist():
    twentysix_twentythree = twentysix_twentythree.append({"top":i[0],"bottom":i[1]},ignore_index=True)
twentysix_twentythree
# Out:
#                         top                       bottom dress outer
# 0     gray_none_shortsleeve         gray_none_shortpants   NaN   NaN
# 1     gray_none_shortsleeve          red_none_shortpants   NaN   NaN
# 2     gray_none_shortsleeve        beige_none_shortpants   NaN   NaN
# 3     gray_none_shortsleeve         beige_none_longskirt   NaN   NaN
# 4     gray_none_shortsleeve   black_none_adidaslongpants   NaN   NaN
# ..                      ...                          ...   ...   ...
# 515  black_nike_shortsleeve         black_none_longpants   NaN   NaN
# 516  black_nike_shortsleeve  black_none_adidasshortpants   NaN   NaN
# 517  black_nike_shortsleeve       black_none_joggerpants   NaN   NaN
# 518  black_nike_shortsleeve    lightblue_none_shortpants   NaN   NaN
# 519  black_nike_shortsleeve          blue_none_longskirt   NaN   NaN
#
# [520 rows x 4 columns]

# %%
# twentysix_twentythree_2 : dress
idx_d2=df3[df3["26"]=="None"].index
twentysix_twentythree_2 = df3["26"].drop(idx_d2)
for i in twentysix_twentythree_2.tolist():
    if i != None:
        print(i)
        twentysix_twentythree = twentysix_twentythree.append({"dress":i},ignore_index=True)
twentysix_twentythree
# Out:
# black_none_sumlongdress
# white_none_sumlongdress
# blue_none_sumlongdress
# red_none_sumlongdress
# beige_none_sumlongdress
# black_none_sumshortdress
# white_none_sumshortdress
# blue_none_sumshortdress
# red_none_sumshortdress
# beige_none_sumshortdress
#                        top                      bottom  \
# 0    gray_none_shortsleeve        gray_none_shortpants
# 1    gray_none_shortsleeve         red_none_shortpants
# 2    gray_none_shortsleeve       beige_none_shortpants
# 3    gray_none_shortsleeve        beige_none_longskirt
# 4    gray_none_shortsleeve  black_none_adidaslongpants
# ..                     ...                         ...
# 525                    NaN                         NaN
# 526                    NaN                         NaN
# 527                    NaN                         NaN
# 528                    NaN                         NaN
# 529                    NaN                         NaN
#
#                         dress outer
# ...

# %%
pd.DataFrame(twentysix_twentythree).to_csv("26_23_fashion.csv",mode="w")

# %% [markdown]
# ### 22 ~ 20도

# %%
twentytwo_twenty= pd.DataFrame(columns=["top","bottom","dress","outer"])

# %%
# twentytwo_twenty_1 : top + bottom
twentytwo_twenty_1= pd.MultiIndex.from_product((set(tt_t1["22-1"])-{"None"}, set(btt_t1["22-1"])-{"None"}))
twentytwo_twenty_1=pd.DataFrame(twentytwo_twenty_1)

for i in twentytwo_twenty_1[0].tolist():
    twentytwo_twenty = twentytwo_twenty.append({"top":i[0],"bottom":i[1]},ignore_index=True)
twentytwo_twenty
# Out:
#                         top                       bottom dress outer
# 0    purple_none_longsleeve         gray_none_shortpants   NaN   NaN
# 1    purple_none_longsleeve          red_none_shortpants   NaN   NaN
# 2    purple_none_longsleeve        beige_none_shortpants   NaN   NaN
# 3    purple_none_longsleeve         beige_none_longskirt   NaN   NaN
# 4    purple_none_longsleeve   black_none_adidaslongpants   NaN   NaN
# ..                      ...                          ...   ...   ...
# 619     red_none_longsleeve         black_none_longpants   NaN   NaN
# 620     red_none_longsleeve  black_none_adidasshortpants   NaN   NaN
# 621     red_none_longsleeve       black_none_joggerpants   NaN   NaN
# 622     red_none_longsleeve    lightblue_none_shortpants   NaN   NaN
# 623     red_none_longsleeve          blue_none_longskirt   NaN   NaN
#
# [624 rows x 4 columns]

# %%
# twentytwo_twenty_2 : top + bottom + outer
twentytwo_twenty_2= pd.MultiIndex.from_product((set(tt_t1["22-2"])-{"None"}, set(btt_t1["22-2"])-{"None"}, set(ptt_t["22"])-{"None"}))
twentytwo_twenty_2=pd.DataFrame(twentytwo_twenty_2)

for i in twentytwo_twenty_2[0].tolist():
    twentytwo_twenty = twentytwo_twenty.append({"top":i[0],"bottom":i[1],'outer':i[2]},ignore_index=True)
twentytwo_twenty
# Out:
#                          top                      bottom dress  \
# 0     purple_none_longsleeve        gray_none_shortpants   NaN
# 1     purple_none_longsleeve         red_none_shortpants   NaN
# 2     purple_none_longsleeve       beige_none_shortpants   NaN
# 3     purple_none_longsleeve        beige_none_longskirt   NaN
# 4     purple_none_longsleeve  black_none_adidaslongpants   NaN
# ...                      ...                         ...   ...
# 1699  black_nike_shortsleeve      black_none_joggerpants   NaN
# 1700  black_nike_shortsleeve      black_none_joggerpants   NaN
# 1701  black_nike_shortsleeve         blue_none_longskirt   NaN
# 1702  black_nike_shortsleeve         blue_none_longskirt   NaN
# 1703  black_nike_shortsleeve         blue_none_longskirt   NaN
#
#                     outer
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# ...

# %%
# twentytwo_twenty_3 : dress
idx_d3=df3[df3["22-1"]=="None"].index
twentytwo_twenty_3 = df3["22-1"].drop(idx_d3)
for i in twentytwo_twenty_3.tolist():
    if i != None:
        print(i)
        twentytwo_twenty = twentytwo_twenty.append({"dress":i},ignore_index=True)
twentytwo_twenty
# Out:
# black_none_winshortdress
# white_none_winshortdress
# blue_none_winshortdress
# red_none_winshortdress
# beige_none_winshortdress
#                          top                      bottom  \
# 0     purple_none_longsleeve        gray_none_shortpants
# 1     purple_none_longsleeve         red_none_shortpants
# 2     purple_none_longsleeve       beige_none_shortpants
# 3     purple_none_longsleeve        beige_none_longskirt
# 4     purple_none_longsleeve  black_none_adidaslongpants
# ...                      ...                         ...
# 1704                     NaN                         NaN
# 1705                     NaN                         NaN
# 1706                     NaN                         NaN
# 1707                     NaN                         NaN
# 1708                     NaN                         NaN
#
#                          dress outer
# 0                          NaN   NaN
# 1                          NaN   NaN
# ...

# %%
# twentytwo_twenty_4 : dress + outer
twentytwo_twenty_4= pd.MultiIndex.from_product((set(dtt_t1["22-2"])-{"None"}, set(ptt_t["22"])-{"None"}))
twentytwo_twenty_4=pd.DataFrame(twentytwo_twenty_4)

for i in twentytwo_twenty_4[0].tolist():
    twentytwo_twenty = twentytwo_twenty.append({"dress":i[0],"outer":i[1]},ignore_index=True)
twentytwo_twenty
# Out:
#                          top                      bottom  \
# 0     purple_none_longsleeve        gray_none_shortpants
# 1     purple_none_longsleeve         red_none_shortpants
# 2     purple_none_longsleeve       beige_none_shortpants
# 3     purple_none_longsleeve        beige_none_longskirt
# 4     purple_none_longsleeve  black_none_adidaslongpants
# ...                      ...                         ...
# 1734                     NaN                         NaN
# 1735                     NaN                         NaN
# 1736                     NaN                         NaN
# 1737                     NaN                         NaN
# 1738                     NaN                         NaN
#
#                         dress                outer
# 0                         NaN                  NaN
# 1                         NaN                  NaN
# 2                         NaN                  NaN
# 3                         NaN                  NaN
# ...

# %%
pd.DataFrame(twentytwo_twenty).to_csv("22_20_fashion.csv",mode="w")

# %% [markdown]
# ### 19 ~ 17도

# %%
nineteen_seventeen= pd.DataFrame(columns=["top","bottom","dress","outer"])

# %%
# nineteen_seventeen_1 : top + bottom + outer
nineteen_seventeen_1= pd.MultiIndex.from_product((set(on_os1["19-1"])-{"None"}, set(bon_os1["19-1"])-{"None"},set(pon_os1["19-1"])-{"None"} ))
nineteen_seventeen_1=pd.DataFrame(nineteen_seventeen_1)

for i in nineteen_seventeen_1[0].tolist():
    nineteen_seventeen = nineteen_seventeen.append({"top":i[0],"bottom":i[1],'outer':i[2]},ignore_index=True)
nineteen_seventeen
# Out:
#                          top                bottom dress  \
# 0     purple_none_longsleeve  beige_none_longskirt   NaN
# 1     purple_none_longsleeve  beige_none_longskirt   NaN
# 2     purple_none_longsleeve  beige_none_longskirt   NaN
# 3     purple_none_longsleeve  beige_none_longskirt   NaN
# 4     purple_none_longsleeve  beige_none_longskirt   NaN
# ...                      ...                   ...   ...
# 3451     red_none_longsleeve   blue_none_longskirt   NaN
# 3452     red_none_longsleeve   blue_none_longskirt   NaN
# 3453     red_none_longsleeve   blue_none_longskirt   NaN
# 3454     red_none_longsleeve   blue_none_longskirt   NaN
# 3455     red_none_longsleeve   blue_none_longskirt   NaN
#
#                                     outer
# 0                         black_none_vest
# 1                     brown_none_cardigan
# 2                          gray_none_vest
# 3                        gray_none_hoodie
# 4                      gray_none_cardigan
# ...

# %%
# nineteen_seventeen_2 : top + bottom 
nineteen_seventeen_2= pd.MultiIndex.from_product((set(on_os1["19-2"])-{"None"}, set(bon_os1["19-2"])-{"None"}))
nineteen_seventeen_2=pd.DataFrame(nineteen_seventeen_2)

for i in nineteen_seventeen_2[0].tolist():
    nineteen_seventeen = nineteen_seventeen.append({"top":i[0],"bottom":i[1]},ignore_index=True)
nineteen_seventeen
# Out:
#                          top                 bottom dress                outer
# 0     purple_none_longsleeve   beige_none_longskirt   NaN      black_none_vest
# 1     purple_none_longsleeve   beige_none_longskirt   NaN  brown_none_cardigan
# 2     purple_none_longsleeve   beige_none_longskirt   NaN       gray_none_vest
# 3     purple_none_longsleeve   beige_none_longskirt   NaN     gray_none_hoodie
# 4     purple_none_longsleeve   beige_none_longskirt   NaN   gray_none_cardigan
# ...                      ...                    ...   ...                  ...
# 3515     black_none_longneat   white_none_longpants   NaN                  NaN
# 3516     black_none_longneat  beige_none_shortskirt   NaN                  NaN
# 3517     black_none_longneat   beige_none_longpants   NaN                  NaN
# 3518     black_none_longneat   black_none_longpants   NaN                  NaN
# 3519     black_none_longneat    blue_none_longskirt   NaN                  NaN
#
# [3520 rows x 4 columns]

# %%
# nineteen_seventeen_3 : dress
idx_d4=df3[df3["19"]=="None"].index
nineteen_seventeen_3 = df3["19"].drop(idx_d4)
for i in nineteen_seventeen_3.tolist():
    if i != None:
        print(i)
        nineteen_seventeen = nineteen_seventeen.append({"dress":i},ignore_index=True)
nineteen_seventeen
# Out:
# black_none_winlongdress
# white_none_winlongdress
# blue_none_winlongdress
# red_none_winlongdress
# beige_none_winlongdress
# black_none_winshortdress
# white_none_winshortdress
# blue_none_winshortdress
# red_none_winshortdress
# beige_none_winshortdress
#                          top                bottom                     dress  \
# 0     purple_none_longsleeve  beige_none_longskirt                       NaN
# 1     purple_none_longsleeve  beige_none_longskirt                       NaN
# 2     purple_none_longsleeve  beige_none_longskirt                       NaN
# 3     purple_none_longsleeve  beige_none_longskirt                       NaN
# 4     purple_none_longsleeve  beige_none_longskirt                       NaN
# ...                      ...                   ...                       ...
# 3525                     NaN                   NaN  black_none_winshortdress
# 3526                     NaN                   NaN  white_none_winshortdress
# ...

# %%
# nineteen_seventeen_4 : dress + outer
nineteen_seventeen_4= pd.MultiIndex.from_product((nineteen_seventeen_3.to_list(), set(pon_os1["19-2"])-{"None"}))
nineteen_seventeen_4=pd.DataFrame(nineteen_seventeen_4)

for i in nineteen_seventeen_4[0].tolist():
    nineteen_seventeen = nineteen_seventeen.append({"dress":i[0],"outer":i[1]},ignore_index=True)
nineteen_seventeen
# Out:
#                          top                bottom                     dress  \
# 0     purple_none_longsleeve  beige_none_longskirt                       NaN
# 1     purple_none_longsleeve  beige_none_longskirt                       NaN
# 2     purple_none_longsleeve  beige_none_longskirt                       NaN
# 3     purple_none_longsleeve  beige_none_longskirt                       NaN
# 4     purple_none_longsleeve  beige_none_longskirt                       NaN
# ...                      ...                   ...                       ...
# 3565                     NaN                   NaN    red_none_winshortdress
# 3566                     NaN                   NaN  beige_none_winshortdress
# 3567                     NaN                   NaN  beige_none_winshortdress
# 3568                     NaN                   NaN  beige_none_winshortdress
# 3569                     NaN                   NaN  beige_none_winshortdress
#
#                     outer
# ...

# %%
pd.DataFrame(nineteen_seventeen).to_csv("19_17_fashion.csv",mode="w")

# %% [markdown]
# ### 16 ~ 10도

# %%
sixteen_ten= pd.DataFrame(columns=["top","bottom","dress","outer"])

# %%
# sixteen_ten_1: top + bottom + outer
sixteen_ten_1= pd.MultiIndex.from_product((set(os_o1['16-1'])-{"None"}, set(bos_o1["16"])-{"None"}, set(pos_o1["16-1"])-{"None"}))
sixteen_ten_1=pd.DataFrame(sixteen_ten_1)

for i in sixteen_ten_1[0].tolist():
    sixteen_ten = sixteen_ten.append({"top":i[0],"bottom":i[1],"outer":i[2]},ignore_index=True)
sixteen_ten
# Out:
#                          top                bottom dress  \
# 0     purple_none_longsleeve  beige_none_longskirt   NaN
# 1     purple_none_longsleeve  beige_none_longskirt   NaN
# 2     purple_none_longsleeve  beige_none_longskirt   NaN
# 3     purple_none_longsleeve  beige_none_longskirt   NaN
# 4     purple_none_longsleeve  beige_none_longskirt   NaN
# ...                      ...                   ...   ...
# 6043     red_none_longsleeve   blue_none_longskirt   NaN
# 6044     red_none_longsleeve   blue_none_longskirt   NaN
# 6045     red_none_longsleeve   blue_none_longskirt   NaN
# 6046     red_none_longsleeve   blue_none_longskirt   NaN
# 6047     red_none_longsleeve   blue_none_longskirt   NaN
#
#                        outer
# 0           gray_none_blazer
# 1        brown_none_cardigan
# 2     black_none_riderjacket
# 3           gray_none_hoodie
# 4         gray_none_cardigan
# ...                      ...
# 6043          black_none_ma1
# 6044       black_none_blazer
# ...

# %%
# sixteen_ten_2: top + bottom + vest + outer
sixteen_ten_2= pd.MultiIndex.from_product((set(os_o1['16-2'])-{"None"}, set(bos_o1["16"])-{"None"}, set(pos_o1["16-2"])-{"None"}, set(vest)-{"None"}))
sixteen_ten_2=pd.DataFrame(sixteen_ten_2)

for i in sixteen_ten_2[0].tolist():
    sixteen_ten = sixteen_ten.append({"top":i[0],"bottom":i[1],"outer":i[2],"vest":i[3]},ignore_index=True)
sixteen_ten
# Out:
#                          top                bottom dress  \
# 0     purple_none_longsleeve  beige_none_longskirt   NaN
# 1     purple_none_longsleeve  beige_none_longskirt   NaN
# 2     purple_none_longsleeve  beige_none_longskirt   NaN
# 3     purple_none_longsleeve  beige_none_longskirt   NaN
# 4     purple_none_longsleeve  beige_none_longskirt   NaN
# ...                      ...                   ...   ...
# 9499     red_none_longsleeve   blue_none_longskirt   NaN
# 9500     red_none_longsleeve   blue_none_longskirt   NaN
# 9501     red_none_longsleeve   blue_none_longskirt   NaN
# 9502     red_none_longsleeve   blue_none_longskirt   NaN
# 9503     red_none_longsleeve   blue_none_longskirt   NaN
#
#                        outer                 vest
# 0           gray_none_blazer                  NaN
# 1        brown_none_cardigan                  NaN
# 2     black_none_riderjacket                  NaN
# 3           gray_none_hoodie                  NaN
# ...

# %%
# sixteen_ten_3 : dress + outer
sixteen_ten_3= pd.MultiIndex.from_product((nineteen_seventeen_3.to_list(), set(pos_o1["16-1"])-{"None"}))
sixteen_ten_3=pd.DataFrame(sixteen_ten_3)

for i in sixteen_ten_3[0].tolist():
    sixteen_ten = sixteen_ten.append({"dress":i[0],"outer":i[1]},ignore_index=True)
sixteen_ten
# Out:
#                          top                bottom                     dress  \
# 0     purple_none_longsleeve  beige_none_longskirt                       NaN
# 1     purple_none_longsleeve  beige_none_longskirt                       NaN
# 2     purple_none_longsleeve  beige_none_longskirt                       NaN
# 3     purple_none_longsleeve  beige_none_longskirt                       NaN
# 4     purple_none_longsleeve  beige_none_longskirt                       NaN
# ...                      ...                   ...                       ...
# 9619                     NaN                   NaN  beige_none_winshortdress
# 9620                     NaN                   NaN  beige_none_winshortdress
# 9621                     NaN                   NaN  beige_none_winshortdress
# 9622                     NaN                   NaN  beige_none_winshortdress
# 9623                     NaN                   NaN  beige_none_winshortdress
#
#                        outer vest
# ...

# %%
# sixteen_ten_4 : dress + vest + outer
sixteen_ten_4= pd.MultiIndex.from_product((nineteen_seventeen_3.to_list(), set(pos_o1["16-2"])-{"None"},set(vest)-{"None"}))
sixteen_ten_4=pd.DataFrame(sixteen_ten_4)

for i in sixteen_ten_4[0].tolist():
    sixteen_ten = sixteen_ten.append({"dress":i[0],"outer":i[1],"vest":i[2]},ignore_index=True)
sixteen_ten
# Out:
#                          top                bottom                     dress  \
# 0     purple_none_longsleeve  beige_none_longskirt                       NaN
# 1     purple_none_longsleeve  beige_none_longskirt                       NaN
# 2     purple_none_longsleeve  beige_none_longskirt                       NaN
# 3     purple_none_longsleeve  beige_none_longskirt                       NaN
# 4     purple_none_longsleeve  beige_none_longskirt                       NaN
# ...                      ...                   ...                       ...
# 9699                     NaN                   NaN  beige_none_winshortdress
# 9700                     NaN                   NaN  beige_none_winshortdress
# 9701                     NaN                   NaN  beige_none_winshortdress
# 9702                     NaN                   NaN  beige_none_winshortdress
# 9703                     NaN                   NaN  beige_none_winshortdress
#
# ...

# %%
pd.DataFrame(sixteen_ten).to_csv("16_10_fashion.csv",mode="w")

# %% [markdown]
# ### 9 ~ 6도

# %%
nine_six= pd.DataFrame(columns=["top","bottom","dress","outer","vest"])

# %%
# nine_six_1: top + bottom + outer
nine_six_1= pd.MultiIndex.from_product((set(n_s1['9-1'])-{"None"}, set(bn_s1["9"])-{"None"}, set(pn_s1["9-1"])-{"None"}))
nine_six_1=pd.DataFrame(nine_six_1)

for i in nine_six_1[0].tolist():
    nine_six = nine_six.append({"top":i[0],"bottom":i[1],"outer":i[2]},ignore_index=True)
nine_six
# Out:
#                          top                bottom dress  \
# 0     purple_none_longsleeve  beige_none_longskirt   NaN
# 1     purple_none_longsleeve  beige_none_longskirt   NaN
# 2     purple_none_longsleeve  beige_none_longskirt   NaN
# 3     purple_none_longsleeve  beige_none_longskirt   NaN
# 4     purple_none_longsleeve  beige_none_longskirt   NaN
# ...                      ...                   ...   ...
# 2179     red_none_longsleeve  white_none_longpants   NaN
# 2180     red_none_longsleeve  white_none_longpants   NaN
# 2181     red_none_longsleeve  white_none_longpants   NaN
# 2182     red_none_longsleeve  white_none_longpants   NaN
# 2183     red_none_longsleeve  white_none_longpants   NaN
#
#                        outer vest
# 0             gray_none_coat  NaN
# 1     black_none_riderjacket  NaN
# 2            black_none_coat  NaN
# 3            brown_none_coat  NaN
# 4           black_none_parka  NaN
# ...                      ...  ...
# ...

# %%
# nine_six_2: top + bottom + vest + outer
nine_six_2= pd.MultiIndex.from_product((set(n_s1['9-2'])-{"None"}, set(bn_s1["9"])-{"None"}, set(pn_s1["9-2"])-{"None"} ,set(vest)-{"None"}))
nine_six_2=pd.DataFrame(nine_six_2)

for i in nine_six_2[0].tolist():
    nine_six = nine_six.append({"top":i[0],"bottom":i[1],"outer":i[2],"vest":i[3]},ignore_index=True)
nine_six
# Out:
#                          top                bottom dress  \
# 0     purple_none_longsleeve  beige_none_longskirt   NaN
# 1     purple_none_longsleeve  beige_none_longskirt   NaN
# 2     purple_none_longsleeve  beige_none_longskirt   NaN
# 3     purple_none_longsleeve  beige_none_longskirt   NaN
# 4     purple_none_longsleeve  beige_none_longskirt   NaN
# ...                      ...                   ...   ...
# 5299     red_none_longsleeve  white_none_longpants   NaN
# 5300     red_none_longsleeve  white_none_longpants   NaN
# 5301     red_none_longsleeve  white_none_longpants   NaN
# 5302     red_none_longsleeve  white_none_longpants   NaN
# 5303     red_none_longsleeve  white_none_longpants   NaN
#
#                        outer                 vest
# 0             gray_none_coat                  NaN
# 1     black_none_riderjacket                  NaN
# 2            black_none_coat                  NaN
# 3            brown_none_coat                  NaN
# ...

# %%
# nine_six_3: top + bottom + outer
nine_six_3= pd.MultiIndex.from_product((set(n_s1['9-2'])-{"None"}, set(bn_s1["9"])-{"None"}, set(pn_s1["9-3_1"])-{"None"} ,set(pn_s1["9-3_2"])-{"None"}))
nine_six_3=pd.DataFrame(nine_six_3)

for i in nine_six_3[0].tolist():
    nine_six = nine_six.append({"top":i[0],"bottom":i[1],"outer":i[2],"outer2":i[3]},ignore_index=True)
nine_six
# Out:
#                           top                bottom dress  \
# 0      purple_none_longsleeve  beige_none_longskirt   NaN
# 1      purple_none_longsleeve  beige_none_longskirt   NaN
# 2      purple_none_longsleeve  beige_none_longskirt   NaN
# 3      purple_none_longsleeve  beige_none_longskirt   NaN
# 4      purple_none_longsleeve  beige_none_longskirt   NaN
# ...                       ...                   ...   ...
# 16531     red_none_longsleeve  white_none_longpants   NaN
# 16532     red_none_longsleeve  white_none_longpants   NaN
# 16533     red_none_longsleeve  white_none_longpants   NaN
# 16534     red_none_longsleeve  white_none_longpants   NaN
# 16535     red_none_longsleeve  white_none_longpants   NaN
#
#                         outer vest                  outer2
# 0              gray_none_coat  NaN                     NaN
# 1      black_none_riderjacket  NaN                     NaN
# 2             black_none_coat  NaN                     NaN
# ...

# %%
# nine_six_4: dress + outer
nine_six_4= pd.MultiIndex.from_product((nineteen_seventeen_3.to_list(), set(pn_s1["9-1"])-{"None"}))
nine_six_4=pd.DataFrame(nine_six_4)

for i in nine_six_4[0].tolist():
    nine_six = nine_six.append({"dress":i[0],"outer":i[1]},ignore_index=True)
nine_six
# Out:
#                           top                bottom                     dress  \
# 0      purple_none_longsleeve  beige_none_longskirt                       NaN
# 1      purple_none_longsleeve  beige_none_longskirt                       NaN
# 2      purple_none_longsleeve  beige_none_longskirt                       NaN
# 3      purple_none_longsleeve  beige_none_longskirt                       NaN
# 4      purple_none_longsleeve  beige_none_longskirt                       NaN
# ...                       ...                   ...                       ...
# 16591                     NaN                   NaN  beige_none_winshortdress
# 16592                     NaN                   NaN  beige_none_winshortdress
# 16593                     NaN                   NaN  beige_none_winshortdress
# 16594                     NaN                   NaN  beige_none_winshortdress
# 16595                     NaN                   NaN  beige_none_winshortdress
#
# ...

# %%
# nine_six_5:  dress + vest + outer
nine_six_5= pd.MultiIndex.from_product((nineteen_seventeen_3.to_list(), set(pn_s1["9-1"])-{"None"}, set(vest)-{"None"}))
nine_six_5=pd.DataFrame(nine_six_5)

for i in nine_six_5[0].tolist():
    nine_six = nine_six.append({"dress":i[0],"outer":i[1],"vest":i[2]},ignore_index=True)
nine_six
# Out:
#                           top                bottom                     dress  \
# 0      purple_none_longsleeve  beige_none_longskirt                       NaN
# 1      purple_none_longsleeve  beige_none_longskirt                       NaN
# 2      purple_none_longsleeve  beige_none_longskirt                       NaN
# 3      purple_none_longsleeve  beige_none_longskirt                       NaN
# 4      purple_none_longsleeve  beige_none_longskirt                       NaN
# ...                       ...                   ...                       ...
# 16711                     NaN                   NaN  beige_none_winshortdress
# 16712                     NaN                   NaN  beige_none_winshortdress
# 16713                     NaN                   NaN  beige_none_winshortdress
# 16714                     NaN                   NaN  beige_none_winshortdress
# 16715                     NaN                   NaN  beige_none_winshortdress
#
# ...

# %%
pd.DataFrame(nine_six).to_csv("9_6_fashion.csv",mode="w")

# %% [markdown]
# ### 5 ~ 도

# %%
five= pd.DataFrame(columns=["top","bottom","dress","outer","vest","outer2"])

# %%
# five_1: top + bottom + outer
five_1= pd.MultiIndex.from_product((set(f1["5-1"])-{"None"}, set(bn_s1["9"])-{"None"}, set(pf1["5-1"])-{"None"}))
five_1=pd.DataFrame(five_1)

for i in five_1[0].tolist():
    five = five.append({"top":i[0],"bottom":i[1],"outer":i[2]},ignore_index=True)
five
# Out:
#                          top                bottom dress             outer  \
# 0     purple_none_longsleeve  beige_none_longskirt   NaN    gray_none_coat
# 1     purple_none_longsleeve  beige_none_longskirt   NaN   black_none_coat
# 2     purple_none_longsleeve  beige_none_longskirt   NaN   brown_none_coat
# 3     purple_none_longsleeve  beige_none_longskirt   NaN  black_none_parka
# 4     purple_none_longsleeve  beige_none_longskirt   NaN  white_none_parka
# ...                      ...                   ...   ...               ...
# 1815     red_none_longsleeve  white_none_longpants   NaN    gray_none_coat
# 1816     red_none_longsleeve  white_none_longpants   NaN   black_none_coat
# 1817     red_none_longsleeve  white_none_longpants   NaN   brown_none_coat
# 1818     red_none_longsleeve  white_none_longpants   NaN  black_none_parka
# 1819     red_none_longsleeve  white_none_longpants   NaN  white_none_parka
#
#      vest outer2
# 0     NaN    NaN
# 1     NaN    NaN
# ...

# %%
# five_2: top + bottom + vest + outer
five_2= pd.MultiIndex.from_product((set(f1["5-2"])-{"None"}, set(bn_s1["9"])-{"None"}, set(pf1["5-1"])-{"None"}, set(vest)-{"None"}))
five_2=pd.DataFrame(five_2)

for i in five_2[0].tolist():
    five = five.append({"top":i[0],"bottom":i[1],"outer":i[2],"vest":i[3]},ignore_index=True)
five
# Out:
#                          top                bottom dress             outer  \
# 0     purple_none_longsleeve  beige_none_longskirt   NaN    gray_none_coat
# 1     purple_none_longsleeve  beige_none_longskirt   NaN   black_none_coat
# 2     purple_none_longsleeve  beige_none_longskirt   NaN   brown_none_coat
# 3     purple_none_longsleeve  beige_none_longskirt   NaN  black_none_parka
# 4     purple_none_longsleeve  beige_none_longskirt   NaN  white_none_parka
# ...                      ...                   ...   ...               ...
# 4935     red_none_longsleeve  white_none_longpants   NaN   brown_none_coat
# 4936     red_none_longsleeve  white_none_longpants   NaN  black_none_parka
# 4937     red_none_longsleeve  white_none_longpants   NaN  black_none_parka
# 4938     red_none_longsleeve  white_none_longpants   NaN  white_none_parka
# 4939     red_none_longsleeve  white_none_longpants   NaN  white_none_parka
#
#                      vest outer2
# 0                     NaN    NaN
# ...

# %%
# five_3: top + bottom + outer + outer
five_3= pd.MultiIndex.from_product((set(f1["5-1"])-{"None"}, set(bn_s1["9"])-{"None"}, set(pf1["5-2_1"])-{"None"},set(pf1["5-2_2"])-{"None"} ))
five_3=pd.DataFrame(five_3)

for i in five_3[0].tolist():
    five = five.append({"top":i[0],"bottom":i[1],"outer":i[2],"outer2":i[3]},ignore_index=True)
five
# Out:
#                           top                bottom dress              outer  \
# 0      purple_none_longsleeve  beige_none_longskirt   NaN     gray_none_coat
# 1      purple_none_longsleeve  beige_none_longskirt   NaN    black_none_coat
# 2      purple_none_longsleeve  beige_none_longskirt   NaN    brown_none_coat
# 3      purple_none_longsleeve  beige_none_longskirt   NaN   black_none_parka
# 4      purple_none_longsleeve  beige_none_longskirt   NaN   white_none_parka
# ...                       ...                   ...   ...                ...
# 19495     red_none_longsleeve  white_none_longpants   NaN  brown_none_hoodie
# 19496     red_none_longsleeve  white_none_longpants   NaN  brown_none_hoodie
# 19497     red_none_longsleeve  white_none_longpants   NaN  brown_none_hoodie
# 19498     red_none_longsleeve  white_none_longpants   NaN  brown_none_hoodie
# 19499     red_none_longsleeve  white_none_longpants   NaN  brown_none_hoodie
#
#       vest            outer2
# ...

# %%
# five_4: top + bottom + vest + outer + outer
five_4= pd.MultiIndex.from_product((set(f1["5-1"])-{"None"}, set(bn_s1["9"])-{"None"}, set(pf1["5-2_2"])-{"None"},set(pf1["5-2_3"])-{"None"},set(vest)-{"None"} ))
five_4=pd.DataFrame(five_4)

for i in five_4[0].tolist():
    five = five.append({"top":i[0],"bottom":i[1],"outer":i[2],"outer2":i[3],"vest":i[4]},ignore_index=True)
five
# Out:
#                           top                bottom dress             outer  \
# 0      purple_none_longsleeve  beige_none_longskirt   NaN    gray_none_coat
# 1      purple_none_longsleeve  beige_none_longskirt   NaN   black_none_coat
# 2      purple_none_longsleeve  beige_none_longskirt   NaN   brown_none_coat
# 3      purple_none_longsleeve  beige_none_longskirt   NaN  black_none_parka
# 4      purple_none_longsleeve  beige_none_longskirt   NaN  white_none_parka
# ...                       ...                   ...   ...               ...
# 34055     red_none_longsleeve  white_none_longpants   NaN  white_none_parka
# 34056     red_none_longsleeve  white_none_longpants   NaN  white_none_parka
# 34057     red_none_longsleeve  white_none_longpants   NaN  white_none_parka
# 34058     red_none_longsleeve  white_none_longpants   NaN  white_none_parka
# 34059     red_none_longsleeve  white_none_longpants   NaN  white_none_parka
#
#                       vest               outer2
# ...

# %%
# five_5:  dress + outer
five_5= pd.MultiIndex.from_product((nineteen_seventeen_3.to_list(), set(pf1["5-2_2"])-{"None"}))
five_5=pd.DataFrame(five_5)

for i in five_5[0].tolist():
    five = five.append({"dress":i[0],"outer":i[1]},ignore_index=True)
five
# Out:
#                           top                bottom                     dress  \
# 0      purple_none_longsleeve  beige_none_longskirt                       NaN
# 1      purple_none_longsleeve  beige_none_longskirt                       NaN
# 2      purple_none_longsleeve  beige_none_longskirt                       NaN
# 3      purple_none_longsleeve  beige_none_longskirt                       NaN
# 4      purple_none_longsleeve  beige_none_longskirt                       NaN
# ...                       ...                   ...                       ...
# 34105                     NaN                   NaN  beige_none_winshortdress
# 34106                     NaN                   NaN  beige_none_winshortdress
# 34107                     NaN                   NaN  beige_none_winshortdress
# 34108                     NaN                   NaN  beige_none_winshortdress
# 34109                     NaN                   NaN  beige_none_winshortdress
#
# ...

# %%
# five_6:  dress + vest + outer
five_6= pd.MultiIndex.from_product((nineteen_seventeen_3.to_list(), set(pf1["5-2_2"])-{"None"}, set(vest)-{"None"}))
five_6=pd.DataFrame(five_6)

for i in five_6[0].tolist():
    five = five.append({"dress":i[0],"outer":i[1],"vest":i[2]},ignore_index=True)
five
# Out:
#                           top                bottom                     dress  \
# 0      purple_none_longsleeve  beige_none_longskirt                       NaN
# 1      purple_none_longsleeve  beige_none_longskirt                       NaN
# 2      purple_none_longsleeve  beige_none_longskirt                       NaN
# 3      purple_none_longsleeve  beige_none_longskirt                       NaN
# 4      purple_none_longsleeve  beige_none_longskirt                       NaN
# ...                       ...                   ...                       ...
# 34205                     NaN                   NaN  beige_none_winshortdress
# 34206                     NaN                   NaN  beige_none_winshortdress
# 34207                     NaN                   NaN  beige_none_winshortdress
# 34208                     NaN                   NaN  beige_none_winshortdress
# 34209                     NaN                   NaN  beige_none_winshortdress
#
# ...

# %%
# five_7:  dress + outer + outer
five_7= pd.MultiIndex.from_product((nineteen_seventeen_3.to_list(), set(pf1["5-2_2"])-{"None"}, set(pf1["5-2_4"])-{"None"}))
five_7=pd.DataFrame(five_7)

for i in five_7[0].tolist():
    five = five.append({"dress":i[0],"outer":i[1],"outer2":i[2]},ignore_index=True)
five
# Out:
#                           top                bottom                     dress  \
# 0      purple_none_longsleeve  beige_none_longskirt                       NaN
# 1      purple_none_longsleeve  beige_none_longskirt                       NaN
# 2      purple_none_longsleeve  beige_none_longskirt                       NaN
# 3      purple_none_longsleeve  beige_none_longskirt                       NaN
# 4      purple_none_longsleeve  beige_none_longskirt                       NaN
# ...                       ...                   ...                       ...
# 34455                     NaN                   NaN  beige_none_winshortdress
# 34456                     NaN                   NaN  beige_none_winshortdress
# 34457                     NaN                   NaN  beige_none_winshortdress
# 34458                     NaN                   NaN  beige_none_winshortdress
# 34459                     NaN                   NaN  beige_none_winshortdress
#
# ...

# %%
# five_8:  dress + vest + outer + outer
five_8= pd.MultiIndex.from_product((nineteen_seventeen_3.to_list(), set(pf1["5-2_2"])-{"None"}, set(pf1["5-2_3"])-{"None"}, set(vest)-{"None"}))
five_8=pd.DataFrame(five_8)

for i in five_8[0].tolist():
    five = five.append({"dress":i[0],"outer":i[1],"outer2":i[2],"vest":i[3]},ignore_index=True)
five
# Out:
#                           top                bottom                     dress  \
# 0      purple_none_longsleeve  beige_none_longskirt                       NaN
# 1      purple_none_longsleeve  beige_none_longskirt                       NaN
# 2      purple_none_longsleeve  beige_none_longskirt                       NaN
# 3      purple_none_longsleeve  beige_none_longskirt                       NaN
# 4      purple_none_longsleeve  beige_none_longskirt                       NaN
# ...                       ...                   ...                       ...
# 34855                     NaN                   NaN  beige_none_winshortdress
# 34856                     NaN                   NaN  beige_none_winshortdress
# 34857                     NaN                   NaN  beige_none_winshortdress
# 34858                     NaN                   NaN  beige_none_winshortdress
# 34859                     NaN                   NaN  beige_none_winshortdress
#
# ...

# %%
pd.DataFrame(five).to_csv("5_fashion.csv",mode="w")
